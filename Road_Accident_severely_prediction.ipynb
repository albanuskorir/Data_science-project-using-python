# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load your dataset
dataset = pd.read_excel('/content/road_accident.csv.xlsx')
data

data = pd.get_dummies(data, columns=["Weather", "Road Conditions", "Driver Age", "Time of Day", "Location", "Speed Limit", "Alcohol Involvement", "Driver Behavior", "Vehicles Involved", "Severity"])

# Define the independent variables (features) and the dependent variable (target)
X = data.drop(columns=['Severity'])
y = data['Severity']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2):", r2)

# %%
dataset = pd.read_excel('/content/road_accident.csv.xlsx')
data
# Out:
#   Weather Road Conditions  Driver Age Time of Day Location  Speed Limit  \
# 0  winter             Wet          35         Day    Urban           60
# 1  summer             Dry          28       Night    Rural           80
#
#    Alcohol Involvement  Driver Behavior  Vehicles Involved Severity
# 0                    0                1                  2    Minor
# 1                    2                0                  5   Severe

# %%
print("Shape of the dataset:", data.shape)
# Out:
# Shape of the dataset: (2, 10)

# %%
data.describe()
# Out:
#        Driver Age  Speed Limit  Alcohol Involvement  Driver Behavior  \
# count    2.000000     2.000000             2.000000         2.000000
# mean    31.500000    70.000000             1.000000         0.500000
# std      4.949747    14.142136             1.414214         0.707107
# min     28.000000    60.000000             0.000000         0.000000
# 25%     29.750000    65.000000             0.500000         0.250000
# 50%     31.500000    70.000000             1.000000         0.500000
# 75%     33.250000    75.000000             1.500000         0.750000
# max     35.000000    80.000000             2.000000         1.000000
#
#        Vehicles Involved
# count            2.00000
# mean             3.50000
# std              2.12132
# min              2.00000
# 25%              2.75000
# 50%              3.50000
# 75%              4.25000
# max              5.00000
